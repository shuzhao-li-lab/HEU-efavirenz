# %% [markdown]
# # Running mummichog

# %%
# %cd '/Volumes/T7/Li Lab/Projects/HEU/for_github/metab_notebooks/02_heu_metabolomics_analysis/2026-08-12_results/'
# Out:
# /Volumes/T7/Li Lab/Projects/HEU/for_github/metab_notebooks/02_heu_metabolomics_analysis/2026-08-12_results/mummichog_inputs

# %%
# !pwd
# Out:
# /Volumes/T7/Li Lab/Projects/HEU/for_github/metab_notebooks/02_heu_metabolomics_analysis/2026-08-12_results/mummichog_inputs

# %%
# !mummichog
# Out:
#
#     --------------------------------------------
#
#              oO                      ooooooooo
#            oOO   OOOOO  ooooo       ooo oooo
#      oOO   O       ooooo  oooooo ooooo
#     oooO           oooooo         oooo ooooo
#         Oooo   o      OOOOOO   oooo   oooooooo
#             ooooo  oooo
#                  o
#
#     --------------------------------------------
#
# mummichog version 2.7.0
#
#
#     Usage example:
#     python main.py -f mydata.txt -o myoutput
#
#         -f, --infile: single file as input,
#               containing all features with tab-delimited columns
#               m/z, retention time, p-value, statistic score
#
#         -n, --network: network model to use (default human_mfn; models being ported to version 2),
#               [human_mfn, worm, or user supplied file in JSON]
#
#         -o, --output: output file identification string (default 'mcgresult')
#         -k, --workdir: directory for all data files.
# ...

# %%
ls
# Out:
# 2026-08-12_HILIC_neg_HUU_HEU_Cord_volcano_df_mummichog_input.tsv*
# 2026-08-12_HILIC_neg_HUU_HEU_Maternal_volcano_df_mummichog_input.tsv*
# 2026-08-12_HILIC_pos_HUU_HEU_Cord_volcano_df_mummichog_input.tsv*
# 2026-08-12_HILIC_pos_HUU_HEU_Maternal_volcano_df_mummichog_input.tsv*
# 2026-08-12_RP_neg_HUU_HEU_Cord_volcano_df_mummichog_input.tsv*
# 2026-08-12_RP_neg_HUU_HEU_Maternal_volcano_df_mummichog_input.tsv*
# 2026-08-12_RP_pos_HUU_HEU_Cord_volcano_df_mummichog_input.tsv*
# 2026-08-12_RP_pos_HUU_HEU_Maternal_volcano_df_mummichog_input.tsv*
# 2026-08-25_HILIC_neg_Cord_efavirenz_cor_mummichog_input.tsv*
# 2026-08-25_HILIC_neg_Maternal_efavirenz_cor_mummichog_input.tsv*
# 2026-08-25_HILIC_pos_Cord_efavirenz_cor_mummichog_input.tsv*
# 2026-08-25_HILIC_pos_Maternal_efavirenz_cor_mummichog_input.tsv*
# 2026-08-25_RP_neg_Cord_efavirenz_cor_mummichog_input.tsv*
# 2026-08-25_RP_neg_Maternal_efavirenz_cor_mummichog_input.tsv*
# 2026-08-25_RP_pos_Cord_efavirenz_cor_mummichog_input.tsv*
# ...

# %%
# HEU vs HUU comparisons
# !mummichog -k ./mummichog_inputs/ -f 2026-08-12_HILIC_neg_HUU_HEU_Cord_volcano_df_mummichog_input.tsv -o mcg_HEU_vs_HUU_cord_HILIC_neg -m negative -c 1e-4
# !mummichog -k ./mummichog_inputs/ -f 2026-08-12_HILIC_neg_HUU_HEU_Maternal_volcano_df_mummichog_input.tsv -o mcg_HEU_vs_HUU_mothers_HILIC_neg -m negative -c 1e-4

# !mummichog -k ./mummichog_inputs/ -f 2026-08-12_HILIC_pos_HUU_HEU_Cord_volcano_df_mummichog_input.tsv -o mcg_HEU_vs_HUU_cord_HILIC_pos -m positive -c 1e-4
# !mummichog -k ./mummichog_inputs/ -f 2026-08-12_HILIC_pos_HUU_HEU_Maternal_volcano_df_mummichog_input.tsv -o mcg_HEU_vs_HUU_mothers_HILIC_pos -m positive -c 1e-4

# !mummichog -k ./mummichog_inputs/ -f 2026-08-12_RP_neg_HUU_HEU_Cord_volcano_df_mummichog_input.tsv -o mcg_HEU_vs_HUU_cord_RP_neg -m negative -c 1e-4
# !mummichog -k ./mummichog_inputs/ -f 2026-08-12_RP_neg_HUU_HEU_Maternal_volcano_df_mummichog_input.tsv -o mcg_HEU_vs_HUU_mothers_RP_neg -m negative -c 1e-4

# !mummichog -k ./mummichog_inputs/ -f 2026-08-12_RP_pos_HUU_HEU_Cord_volcano_df_mummichog_input.tsv -o mcg_HEU_vs_HUU_cord_RP_pos -m positive -c 1e-4
# !mummichog -k ./mummichog_inputs/ -f 2026-08-12_RP_pos_HUU_HEU_Maternal_volcano_df_mummichog_input.tsv -o mcg_HEU_vs_HUU_mothers_RP_pos -m positive -c 1e-4

# %%
# EFV correlations
# !mummichog -k ./mummichog_inputs/ -f 2026-08-25_HILIC_neg_Cord_efavirenz_cor_mummichog_input.tsv -o mcg_HEU_efv_corr_cord_HILIC_neg -m negative 
# !mummichog -k ./mummichog_inputs/ -f 2026-08-25_HILIC_neg_Maternal_efavirenz_cor_mummichog_input.tsv -o mcg_HEU_efv_corr_mothers_HILIC_neg -m negative 

# !mummichog -k ./mummichog_inputs/ -f 2026-08-25_HILIC_pos_Cord_efavirenz_cor_mummichog_input.tsv -o mcg_HEU_efv_corr_cord_HILIC_pos -m positive 
# !mummichog -k ./mummichog_inputs/ -f 2026-08-25_HILIC_pos_Maternal_efavirenz_cor_mummichog_input.tsv -o mcg_HEU_efv_corr_mothers_HILIC_pos -m positive

# !mummichog -k ./mummichog_inputs/ -f 2026-08-25_RP_neg_Cord_efavirenz_cor_mummichog_input.tsv -o mcg_HEU_efv_corr_cord_RP_neg -m negative 
# !mummichog -k ./mummichog_inputs/ -f 2026-08-25_RP_neg_Maternal_efavirenz_cor_mummichog_input.tsv -o mcg_HEU_efv_corr_mothers_RP_neg -m negative

# !mummichog -k ./mummichog_inputs/ -f 2026-08-25_RP_pos_Cord_efavirenz_cor_mummichog_input.tsv -o mcg_HEU_efv_corr_cord_RP_pos -m positive 
# !mummichog -k ./mummichog_inputs/ -f 2026-08-25_RP_pos_Maternal_efavirenz_cor_mummichog_input.tsv -o mcg_HEU_efv_corr_mothers_RP_pos -m positive
